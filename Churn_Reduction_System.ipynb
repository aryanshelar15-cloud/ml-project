# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanshelar15-cloud/ml-project/blob/main/Churn_Reduction_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("/content/customer_churn_large.csv")
le = LabelEncoder()
for col in data.columns:
  data[col] = le.fit_transform(data[col])
X = data.drop('churn', axis =1)
Y = data['churn']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7

# %%
data["Churn_Probability"]= model.predict_proba(X)[:,1]
high_risk = data[data["Churn_Probability"]>0.7]
high_risk.head()
# Out:
#     customer_id  tenure  monthly_charges  total_charges  contract_type  \
# 2             2      60               88            225              2
# 8             8       1               57            202              1
# 11           11       1               60            396              0
# 22           22      14                5            144              0
# 24           24      61               43            432              2
#
#     internet_service  support_calls  churn  Churn_Probability
# 2                  0              5      1               0.78
# 8                  2              5      0               0.72
# 11                 2              5      1               0.84
# 22                 2              1      1               0.75
# 24                 1              0      1               0.75
