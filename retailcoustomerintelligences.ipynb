# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanshelar15-cloud/ml-project/blob/main/retailcoustomerintelligences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from  sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("/content/customer_segmentation_large.csv")

# %%
X = data.drop("customer_id",axis = 1)
X_scaled = StandardScaler().fit_transform(X)
KMeans = KMeans(n_clusters=4)
data["cluster"]= KMeans.fit_predict(X_scaled)
data.head()
# Out:
#    customer_id  annual_income  spending_score  visits_per_month  \
# 0            1          47843              36                 2
# 1            2          82320              13                 1
# 2            3          49793              12                 9
# 3            4          59516              37                 9
# 4            5         124407              74                 7
#
#    avg_purchase_value  cluster
# 0                5865        3
# 1                1218        3
# 2                1473        1
# 3                3503        0
# 4                 732        1
